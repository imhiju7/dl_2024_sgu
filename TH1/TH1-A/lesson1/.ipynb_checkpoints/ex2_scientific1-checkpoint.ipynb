# %% [markdown]
# # ex2_scientific1
#
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0,1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi*(15 * np.random.rand(N)) ** 2 # 0 to 15 point radi i
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# Mã kiểm tra dữ liệu
print(f"x: len={len(x):d}, [min(x):.2f, max(x):.2f]: 10 samples {x[0:10]}")
print(f"y: len={len(y):d}, [min(y):.2f, max(y):.2f]: 10 samples {y[0:10]}")
print(f"colors: len={len(colors):d}, [min(colors):.2f, max(colors):.2f]: 10 samples {colors[0:10]}")
print(f"area: len={len(area):d}, [min(area):.2f, max(area):.2f]: 10 samples {area[0:10]}")
# Out:
# x: len=50, [min(x):.2f, max(x):.2f]: 10 samples [0.59906405 0.59604154 0.46576188 0.37451289 0.80161853 0.89785391
#  0.32864328 0.54129354 0.7103875  0.68407139]
# y: len=50, [min(y):.2f, max(y):.2f]: 10 samples [0.77568309 0.09893027 0.25990533 0.77066186 0.5433552  0.18902133
#  0.7659712  0.58977053 0.9295811  0.99135341]
# colors: len=50, [min(colors):.2f, max(colors):.2f]: 10 samples [0.34201426 0.75868087 0.92555326 0.60286505 0.20916331 0.95342008
#  0.68583259 0.47910336 0.08596224 0.90650275]
# area: len=50, [min(area):.2f, max(area):.2f]: 10 samples [8.80532950e-02 3.85282383e+02 5.32568862e-03 2.94896247e-01
#  3.09665186e+02 4.19126333e+02 5.16078202e+02 4.92553684e+02
#  1.94203413e+02 1.09732180e+01]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# Hiển thị biểu đồ tán xạ
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ### Kết thúc
